# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'alldatasets.xlsx',sheet_name='Vietnam')

# %%
df.head()
# Out:
#     childid  country      height  stunting_2cat  EDUYRS2   z_score  \
# 0  VN011001  Vietnam  170.000000              1     12.0 -0.493371
# 1  VN011002  Vietnam  153.500000              1     12.0 -0.795860
# 2  VN011003  Vietnam  158.000000              1      8.0 -1.421140
# 3  VN011004  Vietnam  157.500000              0     12.0 -0.539453
# 4  VN011005  Vietnam  157.600006              0     16.0 -0.297198
#
#    timeschool  agegapr1  momeduyrsr1  chsexr1  agemonr1  hhsizer1  wi_newr1  \
# 0         5.0       NaN         12.0        1        91         5  0.561111
# 1        15.0       3.0          9.0        0        92         6  0.546296
# 2         5.0       7.0          6.0        0       100         5  0.455556
# 3        10.0       0.0          9.0        0        94         6  0.592593
# 4        10.0       4.0          0.0        0        95         5  0.466667
#
#    job_cat  pvt_sector        earn    earn_usd
# 0        1           1         0.0    0.000000
# 1        1           1         0.0    0.000000
# 2        2           1  19200000.0  875.313416
# 3        5           1   4600000.0  209.710495
# 4        5           1   2800000.0  127.649872

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   childid        801 non-null    object
#  1   country        801 non-null    object
#  2   height         801 non-null    float64
#  3   stunting_2cat  801 non-null    int64
#  4   EDUYRS2        800 non-null    float64
#  5   z_score        783 non-null    float64
#  6   timeschool     770 non-null    float64
#  7   agegapr1       754 non-null    float64
#  8   momeduyrsr1    783 non-null    float64
#  9   chsexr1        801 non-null    int64
#  10  agemonr1       801 non-null    int64
#  11  hhsizer1       801 non-null    int64
#  12  wi_newr1       800 non-null    float64
#  13  job_cat        801 non-null    int64
#  14  pvt_sector     801 non-null    int64
#  15  earn           801 non-null    float64
#  16  earn_usd       801 non-null    float64
# dtypes: float64(9), int64(6), object(2)
# memory usage: 106.5+ KB

# %%
import statsmodels.api as sm

# %% [markdown]
# # cognition

# %%
#cognition

X = df["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df["z_score"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                z_score   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.062
# Method:                 Least Squares   F-statistic:                     52.95
# Date:                Wed, 12 May 2021   Prob (F-statistic):           8.34e-13
# Time:                        14:40:39   Log-Likelihood:                -1060.1
# No. Observations:                 783   AIC:                             2124.
# Df Residuals:                     781   BIC:                             2134.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.1185      0.040      2.968      0.003       0.040       0.197
# stunting_2cat    -0.5350      0.074     -7.277      0.000      -0.679      -0.391
# ==============================================================================
# Omnibus:                       33.945   Durbin-Watson:                   1.401
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.548
# Skew:                          -0.500   Prob(JB):                     7.02e-09
# Kurtosis:                       3.390   Cond. No.                         2.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Height

# %%
#Height

X = df["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df["height"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 height   R-squared:                       0.092
# Model:                            OLS   Adj. R-squared:                  0.091
# Method:                 Least Squares   F-statistic:                     80.78
# Date:                Wed, 12 May 2021   Prob (F-statistic):           1.80e-18
# Time:                        14:40:39   Log-Likelihood:                -2726.3
# No. Observations:                 801   AIC:                             5457.
# Df Residuals:                     799   BIC:                             5466.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           162.6362      0.306    531.534      0.000     162.036     163.237
# stunting_2cat    -5.0879      0.566     -8.988      0.000      -6.199      -3.977
# ==============================================================================
# Omnibus:                       17.900   Durbin-Watson:                   2.086
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               10.763
# Skew:                           0.114   Prob(JB):                      0.00460
# Kurtosis:                       2.480   Cond. No.                         2.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # education

# %%
#education

X = df["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df["EDUYRS2"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                EDUYRS2   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     26.62
# Date:                Wed, 12 May 2021   Prob (F-statistic):           3.13e-07
# Time:                        14:40:39   Log-Likelihood:                -2070.5
# No. Observations:                 800   AIC:                             4145.
# Df Residuals:                     798   BIC:                             4154.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            11.6825      0.135     86.298      0.000      11.417      11.948
# stunting_2cat    -1.2941      0.251     -5.159      0.000      -1.787      -0.802
# ==============================================================================
# Omnibus:                        1.129   Durbin-Watson:                   1.785
# Prob(Omnibus):                  0.569   Jarque-Bera (JB):                1.174
# Skew:                          -0.041   Prob(JB):                        0.556
# Kurtosis:                       2.832   Cond. No.                         2.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # cognition covariates

# %%
df.columns
# Out:
# Index(['childid', 'country', 'height', 'stunting_2cat', 'EDUYRS2', 'z_score',
#        'timeschool', 'agegapr1', 'momeduyrsr1', 'chsexr1', 'agemonr1',
#        'hhsizer1', 'wi_newr1', 'job_cat', 'pvt_sector', 'earn', 'earn_usd'],
#       dtype='object')

# %%
X = df[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df["z_score"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                z_score   R-squared:                       0.329
# Model:                            OLS   Adj. R-squared:                  0.323
# Method:                 Least Squares   F-statistic:                     50.60
# Date:                Wed, 12 May 2021   Prob (F-statistic):           1.28e-58
# Time:                        14:40:40   Log-Likelihood:                -867.98
# No. Observations:                 729   AIC:                             1752.
# Df Residuals:                     721   BIC:                             1789.
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.6660      0.864      0.771      0.441      -1.030       2.362
# stunting_2cat    -0.2925      0.068     -4.326      0.000      -0.425      -0.160
# agemonr1         -0.0104      0.009     -1.146      0.252      -0.028       0.007
# chsexr1          -0.2438      0.060     -4.078      0.000      -0.361      -0.126
# agegapr1          0.0014      0.010      0.139      0.890      -0.019       0.022
# momeduyrsr1       0.0386      0.009      4.480      0.000       0.022       0.056
# hhsizer1         -0.0890      0.020     -4.473      0.000      -0.128      -0.050
# wi_newr1          1.6516      0.166      9.926      0.000       1.325       1.978
# ==============================================================================
# Omnibus:                       20.046   Durbin-Watson:                   1.636
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.185
# Skew:                          -0.417   Prob(JB):                     2.51e-05
# Kurtosis:                       3.019   Cond. No.                     2.80e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.8e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # Height covariates

# %%
X = df[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df["height"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 height   R-squared:                       0.609
# Model:                            OLS   Adj. R-squared:                  0.606
# Method:                 Least Squares   F-statistic:                     164.4
# Date:                Wed, 12 May 2021   Prob (F-statistic):          5.79e-146
# Time:                        14:40:40   Log-Likelihood:                -2232.0
# No. Observations:                 746   AIC:                             4480.
# Df Residuals:                     738   BIC:                             4517.
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           160.3538      5.185     30.929      0.000     150.176     170.532
# stunting_2cat    -5.7180      0.406    -14.074      0.000      -6.516      -4.920
# agemonr1         -0.0233      0.054     -0.429      0.668      -0.130       0.083
# chsexr1          11.0869      0.358     30.984      0.000      10.384      11.789
# agegapr1         -0.0086      0.063     -0.137      0.891      -0.132       0.115
# momeduyrsr1       0.0683      0.052      1.322      0.187      -0.033       0.170
# hhsizer1         -0.1730      0.119     -1.459      0.145      -0.406       0.060
# wi_newr1         -0.5430      0.998     -0.544      0.587      -2.503       1.417
# ==============================================================================
# Omnibus:                        1.210   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.546   Jarque-Bera (JB):                1.059
# Skew:                           0.045   Prob(JB):                        0.589
# Kurtosis:                       3.161   Cond. No.                     2.81e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.81e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # education covariates

# %%
X = df[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df["EDUYRS2"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                EDUYRS2   R-squared:                       0.283
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     41.59
# Date:                Wed, 12 May 2021   Prob (F-statistic):           1.77e-49
# Time:                        14:40:40   Log-Likelihood:                -1824.6
# No. Observations:                 746   AIC:                             3665.
# Df Residuals:                     738   BIC:                             3702.
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             7.9485      3.003      2.647      0.008       2.054      13.843
# stunting_2cat    -0.4222      0.235     -1.794      0.073      -0.884       0.040
# agemonr1          0.0175      0.031      0.557      0.578      -0.044       0.079
# chsexr1          -1.0537      0.207     -5.085      0.000      -1.461      -0.647
# agegapr1         -0.0327      0.036     -0.899      0.369      -0.104       0.039
# momeduyrsr1       0.2279      0.030      7.613      0.000       0.169       0.287
# hhsizer1         -0.0944      0.069     -1.375      0.170      -0.229       0.040
# wi_newr1          3.9978      0.578      6.914      0.000       2.863       5.133
# ==============================================================================
# Omnibus:                        1.451   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.484   Jarque-Bera (JB):                1.531
# Skew:                           0.098   Prob(JB):                        0.465
# Kurtosis:                       2.896   Cond. No.                     2.81e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.81e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
